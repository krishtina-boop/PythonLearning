# %%
#level1
#write a python comment saying Python Variables and constants

#ans:
#Python variables and Constants

#2.Declare a first_name variable and assign a value to it
first_name = "Krishtina"

#2.Declare a last_name variable and assign a value to it
last_name = "Maharjan"

#3.Declare a full_name variable and assign a value to it
full_name = first_name + last_name

#5
is_light_on = True

#6 Declare Multiple variables on one line

a,b,c,d = 5,"krishtina",15.5,True

# %%
#exercise level 2
#1Check the data type of all your variables using type() builtin function
print(type(first_name))
print(type(last_name))
print(type(full_name))
print(type(is_light_on))
print(type(a))
print(type(b))
print(type(c))
print(type(d))



#2 Using the len() built-in function, find the length of yur first name
print(len(first_name))

#3 Compare length of your first_name and last_name
print(len(first_name) == len(last_name))


#4 Declare 6 as num_1 and 4 as num_2
num_1 = 6
num_2 = 4

#A
total = num_1 +num_2

#B
difference = num_1 - num_2

#C
product = num_1 * num_2

#D
division = num_1 / num_2

#E
remainder = num_1 % num_2

#f
exp = num_1 ** num_2
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# 9
# False
