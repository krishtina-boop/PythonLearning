# %%
a = 3
print(3)
# Out:
# 3

# %% [markdown]
# # DATA TYPES

# %%
# COMPLEX DATATYPE
# it is used for quadratic equations not important for ai ml
#with complex data type only j variable can be used


#none datatype

'''
a="" -> Empty string -> none

we only need precise answer while doing ai and data science project so we dont use double (round off hunu bhhayena tesaile double use hunna)

'''



#naming convention
'''
camel case -> used while naming function eg: firstDemo no underscore 
snake case -> used while naming variable eg: first_name all words must be on lower cse


'''
# Out:
# '\ncamel case -> used while naming function eg: firstDemo no underscore \nsnake case -> used while naming variable eg: first_name all words must be on lower cse\n\n\n'

# %%
#input function
firstName = input("Enter your first name: ")
print(firstName)
# Out:
# hello

# %%
# number = int (input("enter a number"))
# print(number)
#note: integer doesnt accept float value but float do accept int value
floatnum = float(input("enter a floating point: "))
print(floatnum)
# Out:
# 12.3

# %%
first_name = input("enter first name: ")
last_name = input("enter last name: ")

print("My name is "+first_name +" "+ last_name+".") #""=> literal character
# Out:
# My name is Krishtina Maharjan.

# %%
#fstring
first_name = input("enter first name: ")
last_name = input("enter last name: ")
age = int(input("enter your age: "))
address = input("enter your adress: ")
qualification = input("enter your qualification: ")

print(f"my name is {first_name+" "+last_name}. I am {age} years old. I live at {address}. I have {qualification}")
# Out:
# my name is Krishtina Maharjan. I am 20 years old. I live at Thecho. I have Mern

# %%
#typecasting  -> check data type
numeric = 3

floatnum = float(numeric)
type(floatnum)
print(floatnum)
# Out:
# 3.0

# %% [markdown]
# #operator

# %%
#operators
''' 
// ->integer / floor division
** - > power



-- logical operator
and => all value true->true
or=> any one value true->true
not->opposite
'''

# %%
a = 5
b = 2
div = a // b #float division removes deccimal value
print(div)
# Out:
# 2

# %%
'''
control statement
if
if-elif
if-elif-else
nested if



loops
for loop
while loop
for else
'''

# %%
temp = 30
if temp >30:
    print("its hot today")

else:
    print("its not hot today")
# Out:
# its not

# %%
a = 50
b =100
c=90

if a>b:
    print("a is greater")

elif b>c:
    print("b is greater")

else:
    print("c is greater")
# Out:
# b is greater

# %%
marks = float(input("enter marks: "))

if marks >=80 and marks <=100:
    print("distinction")

elif marks >=60 and marks<=79.9:
    print("1st division")

elif marks >=50 and marks<=59.9:
    print("2nd division")

elif marks >=40 and marks<=49.9:
    print("3rd division")

elif marks<=39:
    print("fail")

else:
    print("invalid")
# Out:
# 1st division

# %%
subject1 = float(input("enter marks for subject 1: "))
subject2 = float(input("enter marks for subject 2: "))
subject3 = float(input("enter marks for subject 3: "))
subject4 = float(input("enter marks for subject 4: "))
subject5 = float(input("enter marks for subject 5: "))

print("grand total: 500")
total = subject1+subject2+subject3+subject4+subject5


average = total /5
print("total obtained by student: ",total)
print("average obtained by student: ",average)

if average >=80 and average <=100:
    # print("distinction")
    res = "distinction"

elif average >=60 and average<=79.9:
    # print("1st division")
    res = "1st division"

elif average >=50 and average<=59.9:
    # print("2nd division")
    res = "2nd division"

elif average >=40 and average<=49.9:
    # print("3rd division")
    res = "3rd division"

elif average<=39:
    print("fail")

else:
    print("invalid marks")

print("Your result is: ",res)
# Out:
# grand total: 500
# total obtained by student:  430.0
# average obtained by student:  86.0
# Your result is:  distinction

# %%
#len
len('apple') == len("bananan")
# Out:
# False

# %%
True or False and False 
#first of all false and false is performed which provides false and later or is performed that gives us true
#so, false and false = false
# false or ture -> true
#so result is true
''' 
precedence of operator
1. small bracket ()
2. and
3. or
'''
# Out:
# True

# %%
True and  (not(not False)) or (True and(not True))
# Out:
# False

# %%
''' 
BITWISE OPERATOR
bitwise and -> &
used in low level pogramming such as network programming, cryptography
'''
a = 2 #binary: 0010
b = 3 #binary: 0011
#============& 0010
a & b

#result -> 0010 -> 2


#BITWISE Or
a = 2 #binary: 0010
b = 3 #binary: 0011
#============= 0011
a | b
# Out:
# 3

# %%
x =2 
y=2

x==y #equal to => value

x is y #memory address => identity


x=300
y=300
x is y
#result is false
#0 - 256 =>point to same memory address
# Out:
# 140703281492936
# 140703281492936
# False

# %%
#membership operator
#in checks in key not in values
1 in [1,2,3,4,5]

'rh' in 'ramesh'
#false

'a' in {'A','b',2,3}
#false

'a' in {'a':1,'b':2}
#true
# Out:
# True

# %%
#isinstance -> checks what type of value is it
x = 5
isinstance(x, int)
isinstance(x,(float,str))   #string or float
# Out:
# False

# %%
#python gives 17 numbers after decimal point
b = 0.1234567890123456789
print(b)
# Out:
# 0.12345678901234568

# %%
(1.1 +2.2) == 3.3 #false
#floating point doesnt maintain precision
# Out:
# False

# %%
#for maintaining precision
from decimal import Decimal
print(Decimal('1.1')+Decimal('2.2'))

#or
from decimal import Decimal as D #now D is known as alias for Decimal
print(D('1.1')+D('2.2'))

#or
import decimal
print(decimal.Decimal('1.1')+decimal.Decimal('2.2'))
# Out:
# 3.3
# 3.3
# 3.3

# %%
from math import pi
print(pi)
# Out:
# 3.141592653589793

# %%
import math
print(math.pi)
print(math.sqrt(4))
print(math.cos(math.pi)) #cos(pi) = -1
print(math.exp(10))
print(math.log10(1000)) #log10(1000) = 3
print(math.sinh(1))
print(math.factorial(6))
# Out:
# 3.141592653589793
# 2.0
# -1.0
# 22026.465794806718
# 3.0
# 1.1752011936438014
# 720
